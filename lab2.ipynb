# %%
# %load_ext sql
# %sql sqlite:///store.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Задание 1
# Вывести 5 самых больших по размеру (в байтах) треков жанра Blues и формата MPEG. Только название и размер.

# %%
# %%sql
# SELECT t.name AS track_name, t.Bytes AS size
# FROM tracks t
# JOIN genres g ON t.genreid = g.genreid
# JOIN media_types m ON t.MediaTypeId = m.MediaTypeId
# WHERE g.name = 'Blues' AND m.name like 'MPEG_%'
# ORDER BY t.Bytes DESC
# LIMIT 5;
# Out:
#  * sqlite:///store.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-ae8977e3c030> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "SELECT t.name AS track_name, t.Bytes AS size\nFROM tracks t\nJOIN genres g ON t.genreid = g.genreid\nJOIN media_types m ON t.MediaTypeId = m.MediaTypeId\nWHERE g.name = 'Blues' AND m.name like 'MPEG_%'\nORDER BY t.Bytes DESC\nLIMIT 5;\n")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-157> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-156> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#     217
#     218         try:
# --> 219             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     220
#     221             if (
#
# /usr/local/lib/python3.10/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     372             if result and config.feedback:
#     373                 print(interpret_rowcount(result.rowcount))
# --> 374         resultset = ResultSet(result, config)
#     375         if config.autopandas:
#     376             return resultset.DataFrame()
#
# /usr/local/lib/python3.10/dist-packages/sql/run.py in __init__(self, sqlaproxy, config)
#     114                 list.__init__(self, sqlaproxy.fetchall())
#     115             self.field_names = unduplicate_field_names(self.keys)
# --> 116             self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117         else:
#     118             list.__init__(self, [])
#
# KeyError: 'DEFAULT'

# %% [markdown]
# Задание 2
# Вывести названия всех треков и их исполнителей для всех треков жанра Rock, приобретенных сотрудниками Oracle.

# %%
# %%sql
# SELECT T.Name AS TrackTitle, A.Name AS ArtistName
# FROM Tracks T
# JOIN Albums AL ON T.AlbumId = AL.AlbumId
# JOIN Artists A ON AL.ArtistId = A.ArtistId
# JOIN Invoice_Items II ON T.TrackId = II.TrackId
# JOIN Invoices I ON II.InvoiceId = I.InvoiceId
# JOIN Customers C ON I.CustomerId = C.CustomerId
# WHERE T.GenreId IN (SELECT GenreId FROM Genres WHERE Name = 'Rock')
# AND C.Company = 'Oracle';
# Out:
#  * sqlite:///store.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-3ef894db5762> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "SELECT T.Name AS TrackTitle, A.Name AS ArtistName\nFROM Tracks T\nJOIN Albums AL ON T.AlbumId = AL.AlbumId\nJOIN Artists A ON AL.ArtistId = A.ArtistId\nJOIN Invoice_Items II ON T.TrackId = II.TrackId\nJOIN Invoices I ON II.InvoiceId = I.InvoiceId\nJOIN Customers C ON I.CustomerId = C.CustomerId\nWHERE T.GenreId IN (SELECT GenreId FROM Genres WHERE Name = 'Rock')\nAND C.Company = 'Oracle';\n")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-157> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-156> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#     217
#     218         try:
# --> 219             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     220
#     221             if (
#
# /usr/local/lib/python3.10/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     372             if result and config.feedback:
#     373                 print(interpret_rowcount(result.rowcount))
# --> 374         resultset = ResultSet(result, config)
#     375         if config.autopandas:
#     376             return resultset.DataFrame()
#
# /usr/local/lib/python3.10/dist-packages/sql/run.py in __init__(self, sqlaproxy, config)
#     114                 list.__init__(self, sqlaproxy.fetchall())
#     115             self.field_names = unduplicate_field_names(self.keys)
# --> 116             self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117         else:
#     118             list.__init__(self, [])
#
# KeyError: 'DEFAULT'

# %% [markdown]
# Задание 3
# Для каждой компании вывести общее количество купленных джазовых композиций (если 0, можно не выводить).

# %%
# %%sql
# SELECT C.Company, COUNT(T.TrackId) AS JazzTracksPurchased
# FROM Customers C
# JOIN Invoices I ON C.CustomerId = I.CustomerId
# JOIN Invoice_Items II ON I.InvoiceId = II.InvoiceId
# JOIN Tracks T ON II.TrackId = T.TrackId
# JOIN Genres G ON T.GenreId = G.GenreId
# WHERE G.Name = 'Jazz'
# GROUP BY C.Company
# HAVING COUNT(T.TrackId) > 0 AND C.Company not NULL;
# Out:
#  * sqlite:///store.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-f2808fb4d70f> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('sql', '', "SELECT C.Company, COUNT(T.TrackId) AS JazzTracksPurchased\nFROM Customers C\nJOIN Invoices I ON C.CustomerId = I.CustomerId\nJOIN Invoice_Items II ON I.InvoiceId = II.InvoiceId\nJOIN Tracks T ON II.TrackId = T.TrackId\nJOIN Genres G ON T.GenreId = G.GenreId\nWHERE G.Name = 'Jazz'\nGROUP BY C.Company\nHAVING COUNT(T.TrackId) > 0 AND C.Company not NULL;\n")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-157> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-156> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#     217
#     218         try:
# --> 219             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     220
#     221             if (
#
# /usr/local/lib/python3.10/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     372             if result and config.feedback:
#     373                 print(interpret_rowcount(result.rowcount))
# --> 374         resultset = ResultSet(result, config)
#     375         if config.autopandas:
#     376             return resultset.DataFrame()
#
# /usr/local/lib/python3.10/dist-packages/sql/run.py in __init__(self, sqlaproxy, config)
#     114                 list.__init__(self, sqlaproxy.fetchall())
#     115             self.field_names = unduplicate_field_names(self.keys)
# --> 116             self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117         else:
#     118             list.__init__(self, [])
#
# KeyError: 'DEFAULT'

# %% [markdown]
# Задание 4
# Вывести топ 3 плейлиста по продолжительности (продолжительность плейлиста = сумма длин треков в нём). Только название и продолжительность (в часах).

# %%
# %%sql
# SELECT P.Name AS PlaylistName,
#        SUM(T.Milliseconds) / 3600000 AS DurationInHours
# FROM Playlists P
# JOIN Playlist_Track PT ON P.PlaylistId = PT.PlaylistId
# JOIN Tracks T ON PT.TrackId = T.TrackId
# GROUP BY P.PlaylistId
# ORDER BY DurationInHours DESC
# LIMIT 3;
# Out:
#  * sqlite:///store.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-8da813dc1baf> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT P.Name AS PlaylistName,\n       SUM(T.Milliseconds) / 3600000 AS DurationInHours\nFROM Playlists P\nJOIN Playlist_Track PT ON P.PlaylistId = PT.PlaylistId\nJOIN Tracks T ON PT.TrackId = T.TrackId\nGROUP BY P.PlaylistId\nORDER BY DurationInHours DESC\nLIMIT 3;\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-157> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-156> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#     217
#     218         try:
# --> 219             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     220
#     221             if (
#
# /usr/local/lib/python3.10/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     372             if result and config.feedback:
#     373                 print(interpret_rowcount(result.rowcount))
# --> 374         resultset = ResultSet(result, config)
#     375         if config.autopandas:
#     376             return resultset.DataFrame()
#
# /usr/local/lib/python3.10/dist-packages/sql/run.py in __init__(self, sqlaproxy, config)
#     114                 list.__init__(self, sqlaproxy.fetchall())
#     115             self.field_names = unduplicate_field_names(self.keys)
# --> 116             self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117         else:
#     118             list.__init__(self, [])
#
# KeyError: 'DEFAULT'

# %% [markdown]
# Задание 5
# Для каждого набора (жанр, тип медиа) вывести количество треков в них, причем вывести только те наборы, для которых все треки стоят больше 1$ и для которых в наборе есть хотя бы один трек.

# %%
# %%sql
# SELECT g.name AS genre, m.name AS media_type, COUNT(*) AS track_count
# FROM tracks t
# JOIN genres g ON t.genreid = g.genreid
# JOIN media_types m ON t.mediaTypeId = m.mediaTypeId
# WHERE t.unitprice > 1
# GROUP BY g.name, m.name
# HAVING COUNT(*) > 0
# AND COUNT(*) = sum(CASE WHEN t.unitprice > 1 THEN 1 END);
# Out:
#  * sqlite:///store.db
# Done.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-796ed95c4473> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('sql', '', 'SELECT g.name AS genre, m.name AS media_type, COUNT(*) AS track_count\nFROM tracks t\nJOIN genres g ON t.genreid = g.genreid\nJOIN media_types m ON t.mediaTypeId = m.mediaTypeId\nWHERE t.unitprice > 1\nGROUP BY g.name, m.name\nHAVING COUNT(*) > 0\nAND COUNT(*) = sum(CASE WHEN t.unitprice > 1 THEN 1 END);\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# <decorator-gen-157> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-156> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#     217
#     218         try:
# --> 219             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     220
#     221             if (
#
# /usr/local/lib/python3.10/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     372             if result and config.feedback:
#     373                 print(interpret_rowcount(result.rowcount))
# --> 374         resultset = ResultSet(result, config)
#     375         if config.autopandas:
#     376             return resultset.DataFrame()
#
# /usr/local/lib/python3.10/dist-packages/sql/run.py in __init__(self, sqlaproxy, config)
#     114                 list.__init__(self, sqlaproxy.fetchall())
#     115             self.field_names = unduplicate_field_names(self.keys)
# --> 116             self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117         else:
#     118             list.__init__(self, [])
#
# KeyError: 'DEFAULT'
